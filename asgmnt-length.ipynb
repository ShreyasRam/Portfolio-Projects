# %%
import pandas as pd
fab = pd.read_csv("C:/Users/shreyas/Desktop/Fabulyst/assignment - length.csv")

# %%
fab
# Out:
#       styleid                                                Url  \
# 0     1549178  http://myntra.myntassets.com/assets/images/154...
# 1     2477324  http://myntra.myntassets.com/assets/images/247...
# 2     2250042  http://myntra.myntassets.com/assets/images/225...
# 3     2424392  http://myntra.myntassets.com/assets/images/242...
# 4     1022918  http://myntra.myntassets.com/assets/images/102...
# 5     1824635  http://myntra.myntassets.com/assets/images/182...
# 6     1521136  http://myntra.myntassets.com/assets/images/152...
# 7     1246404  http://myntra.myntassets.com/assets/images/124...
# 8     2355044  http://myntra.myntassets.com/assets/images/235...
# 9     2168761  http://myntra.myntassets.com/assets/images/216...
# 10    1662986  http://myntra.myntassets.com/assets/images/166...
# 11    1315886  http://myntra.myntassets.com/assets/images/131...
# 12    1773187  http://myntra.myntassets.com/assets/images/177...
# ...

# %%
fab.head(10)
# Out:
#    styleid                                                Url  len_Fabulyst  \
# 0  1549178  http://myntra.myntassets.com/assets/images/154...   Calf Length
# 1  2477324  http://myntra.myntassets.com/assets/images/247...   Calf Length
# 2  2250042  http://myntra.myntassets.com/assets/images/225...  Ankle Length
# 3  2424392  http://myntra.myntassets.com/assets/images/242...   Calf Length
# 4  1022918  http://myntra.myntassets.com/assets/images/102...  Ankle Length
# 5  1824635  http://myntra.myntassets.com/assets/images/182...   Calf Length
# 6  1521136  http://myntra.myntassets.com/assets/images/152...    Above Knee
# 7  1246404  http://myntra.myntassets.com/assets/images/124...   Calf Length
# 8  2355044  http://myntra.myntassets.com/assets/images/235...   Knee Length
# 9  2168761  http://myntra.myntassets.com/assets/images/216...   Calf Length
#
#      len_Myntra correct? analysis
# 0   Calf Length     True      NaN
# 1   Calf Length     True      NaN
# ...

# %%
tn_fn = fab.analysis[fab["correct?"] == False]

# %%
tn_fn.value_counts()
# Out:
# FN       1543
# TN        909
# OOS        24
# FNDEF       6
# Name: analysis, dtype: int64
